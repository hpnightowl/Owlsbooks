# %% [markdown]
# <a href="https://colab.research.google.com/github/hpnightowl/Owlsbooks/blob/master/Edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

def edgedetectkernel(picture):
  img=cv2.imread(picture)
  gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  img_gaussian=cv2.GaussianBlur(gray,(3,3),0)#canny
  img_canny=cv2.Canny(img,100,200)#sobel
  img_sobelx=cv2.Sobel(img_gaussian,cv2.CV_8U,1,0,ksize=5)
  img_sobely=cv2.Sobel(img_gaussian,cv2.CV_8U,0,1,ksize=5)
  img_sobel=img_sobelx+img_sobely#prewitt
  kernelx=np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
  kernely=np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
  img_prewittx=cv2.filter2D(img_gaussian, -1, kernelx)
  img_prewitty=cv2.filter2D(img_gaussian, -1, kernely)
  cv2_imshow(img)
  cv2_imshow(img_canny)
  cv2_imshow(img_sobelx)
  cv2_imshow(img_sobely)
  cv2_imshow(img_sobel)
  cv2_imshow(img_prewittx)
  cv2_imshow(img_prewitty)
  cv2_imshow(img_prewittx+img_prewitty)

# %%
edgedetectkernel('test_image-12.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FA5DAC06810>
# <PIL.Image.Image image mode=L size=275x183 at 0x7FA5D192A4D0>
# <PIL.Image.Image image mode=L size=275x183 at 0x7FA5D192A4D0>
# <PIL.Image.Image image mode=L size=275x183 at 0x7FA5D192A4D0>
# <PIL.Image.Image image mode=L size=275x183 at 0x7FA5D190AAD0>
# <PIL.Image.Image image mode=L size=275x183 at 0x7FA5D190ADD0>
# <PIL.Image.Image image mode=L size=275x183 at 0x7FA5DAC0A210>
# <PIL.Image.Image image mode=L size=275x183 at 0x7FA5DAC06810>

# %%
edgedetectkernel('test_image-9.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=262x192 at 0x7FA5D1038C90>
# <PIL.Image.Image image mode=L size=262x192 at 0x7FA5DABED0D0>
# <PIL.Image.Image image mode=L size=262x192 at 0x7FA5DABED7D0>
# <PIL.Image.Image image mode=L size=262x192 at 0x7FA5D1082750>
# <PIL.Image.Image image mode=L size=262x192 at 0x7FA5D192AE90>
# <PIL.Image.Image image mode=L size=262x192 at 0x7FA5DABF8950>
# <PIL.Image.Image image mode=L size=262x192 at 0x7FA5D1082750>
# <PIL.Image.Image image mode=L size=262x192 at 0x7FA5DAB6D7D0>
