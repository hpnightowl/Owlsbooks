# %% [markdown]
# <a href="https://colab.research.google.com/github/hpnightowl/Owlsbooks/blob/master/box_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/liver_patient.csv")
data
# Out:
#      Age  Gender  ...  Albumin_and_Globulin_Ratio  liver_disease
# 0     65  Female  ...                        0.90              1
# 1     62    Male  ...                        0.74              1
# 2     62    Male  ...                        0.89              1
# 3     58    Male  ...                        1.00              1
# 4     72    Male  ...                        0.40              1
# ..   ...     ...  ...                         ...            ...
# 578   60    Male  ...                        0.37              0
# 579   40    Male  ...                        1.10              1
# 580   52    Male  ...                        1.00              1
# 581   31    Male  ...                        1.00              1
# 582   38    Male  ...                        1.50              0
#
# [583 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=(10,5))

#matplot
ax = fig.add_subplot(121)
ax.set_title('Box plot Box plot of Total Protiens Seaborn Matplotlib')
data.Total_Protiens.plot(kind='box', ax=ax)


#sns
ax = fig.add_subplot(122)
ax.set_title('Box plot of Total Protiens Seaborn')
sns.boxplot(data.Total_Protiens)

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
